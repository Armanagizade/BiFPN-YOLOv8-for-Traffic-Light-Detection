# %%
from ultralytics import YOLO
import time
# Load the trained model (best.pt or last.pt)
model = YOLO('finalYOLOv8n_40_640_round7/weights/last.pt')

# %%
import time
import numpy as np

# %%
results = model('dayClip9--00896.jpg', save=True)
# Out:
# image 1/1 C:\articles\deep learning 2024\yolov8n results\dayClip9--00896.jpg: 480x640 1 go, 1 goLeft, 40.4ms
# Speed: 7.5ms preprocess, 40.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict2

# %%
np.mean(tt)
# Out:
# 20.625237038964308

# %%
tt
# Out:
# [12.539812663874264,
#  13.292210961317842,
#  13.345458132216732,
#  14.240668183207143,
#  14.333865317909199,
#  14.311123242800601,
#  14.32720639724544,
#  16.578145627307293,
#  14.249182956576096,
#  25.14661198844083,
#  19.97306641015629,
#  19.98943886839572,
#  22.305144595356357,
#  20.075452191435286,
#  21.994483424052692,
#  20.083334530393355,
#  19.781000485764277,
#  25.409244562912704,
#  20.062968472713184,
#  19.97744246303917,
#  19.948652826329933,
#  22.34435731333106,
#  22.003137082093975,
#  20.15077878027923,
#  19.928274813512616,
#  22.169211659927587,
#  22.15223407626492,
#  20.103260192294787,
#  19.993059660228422,
#  25.00688026901017,
#  19.998207252996654,
#  19.976490984082833,
#  20.015194029280956,
#  22.280854409366416,
#  22.087374141635422,
#  19.95501170380802,
#  20.06536798193578,
#  25.112585319123458,
#  20.033166481983876,
#  19.93092633599757,
#  19.92903231937357,
#  25.24256138661531,
#  19.96945285570093,
#  19.986771755601513,
# ...
